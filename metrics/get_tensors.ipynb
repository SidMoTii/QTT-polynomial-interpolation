# %%
import torch as tn

import pickle

device = tn.device("cpu") 
vx = tn.load("./data/turbulence/TN_turbulence/vx_10_1.pt",
               map_location=device,
               weights_only=False,
               pickle_module=pickle)

vy = tn.load("./data/turbulence/TN_turbulence/vy_10_1.pt",
               map_location=device,
               weights_only=False,
               pickle_module=pickle)

vz = tn.load("./data/turbulence/TN_turbulence/vz_10_1.pt",
               map_location=device,
               weights_only=False,
               pickle_module=pickle)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 6
#       3 import pickle
#       5 device = tn.device("cpu")
# ----> 6 vx = tn.load("./data/turbulence/TN_turbulence/vx_10_1.pt",
#       7                map_location=device,
#       8                weights_only=False,
#       9                pickle_module=pickle)
#      11 vy = tn.load("./data/turbulence/TN_turbulence/vy_10_1.pt",
#      12                map_location=device,
#      13                weights_only=False,
#      14                pickle_module=pickle)
#      16 vz = tn.load("./data/turbulence/TN_turbulence/vz_10_1.pt",
#      17                map_location=device,
#      18                weights_only=False,
#      19                pickle_module=pickle)
#
# ...

# %%
# %cd ..

from src.qtt_interpolation.comb import *
# Out:
# C:\Users\siddhartha.morales\AppData\Roaming\Python\Python311\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# c:\Users\siddhartha.morales\OneDrive - Technology Innovation Institute\Documents\GitHub\QTT-polynomial-interpolation
# c:\Users\siddhartha.morales\AppData\Local\Programs\Python\Python311\Lib\site-packages\torchtt\_dmrg.py:19: UserWarning:
# C++ implementation not available. Using pure Python.
#
#   warnings.warn("\x1B\nC++ implementation not available. Using pure Python.\n\033")
# c:\Users\siddhartha.morales\AppData\Local\Programs\Python\Python311\Lib\site-packages\torchtt\_amen.py:21: UserWarning:
# C++ implementation not available. Using pure Python.
#
#   warnings.warn(
# c:\Users\siddhartha.morales\AppData\Local\Programs\Python\Python311\Lib\site-packages\torchtt\solvers.py:21: UserWarning:
# ...

# %%
VX = combqtt_full(vx['cores'])
tn.save(VX, "./data/VX_1.pt")

VY = combqtt_full(vy['cores'])
tn.save(VY, "./data/VY_1.pt")

VZ = combqtt_full(vz['cores'])
tn.save(VZ, "./data/VZ_1.pt")

# %%
184*223
# Out:
# 41032

# %%
(2**-12)**4
# Out:
# 3.552713678800501e-15
